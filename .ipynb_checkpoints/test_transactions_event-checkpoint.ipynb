# %%
from transactions import get_event_transactions

# %%
resp1 = get_event_transactions(9643)
# Out:
# C:\Users\aniru\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
resp1[(resp1["status"] in ["Closed",""])]
# Out:
#             date                        createdat  event_id        refid  ...     status   qty asset  price
# 1563  2022-09-16 2022-09-16 01:00:17.995000+05:30      9643         None  ...     Closed   NaN   NaN    NaN
# 1564  2022-09-15 2022-09-15 23:54:32.806000+05:30      9643  od_X5QQuaTV  ...     Bought  16.0     Y   93.0
# 1565  2022-09-15 2022-09-15 23:54:09.423000+05:30      9643  od_IJhzOP1x  ...       Sold   7.0     Y   59.0
# 1566  2022-09-15 2022-09-15 23:54:07.890000+05:30      9643  od_uof8fN4X  ...       Sold   1.0     N   46.0
# 1567  2022-09-15 2022-09-15 23:54:07.405000+05:30      9643  od_IJhzOP1x  ...       Sold   8.0     Y   59.0
# ...          ...                              ...       ...          ...  ...        ...   ...   ...    ...
# 2465  2022-09-15 2022-09-15 14:11:42.461000+05:30      9643  od_rS6rr8oQ  ...       Sold   1.0     N   43.0
# 2466  2022-09-15 2022-09-15 14:09:27.145000+05:30      9643  od_hLuwfV4Z  ...     Bought   2.0     N   44.0
# ...

# %%
mask1 = resp1["asset"] == "Y"
mask2 = resp1["status"] == "Bought"
yb = resp1[mask1 & mask2]
yb.set_index("createdat")["price"].plot(figsize=(16,8));
mask1 = resp1["asset"] == "Y"
mask2 = resp1["status"] == "Sold"
ys = resp1[mask1 & mask2]
ys.set_index("createdat")["price"].plot(figsize=(16,8));

# %%
mask1 = resp1["asset"] == "N"
mask2 = resp1["status"] == "Bought"
nb = resp1[mask1 & mask2]
nb.set_index("createdat")["price"].plot(figsize=(16,8));
mask1 = resp1["asset"] == "N"
mask2 = resp1["status"] == "Sold"
ns = resp1[mask1 & mask2]
ns.set_index("createdat")["price"].plot(figsize=(16,8));

# %%
# Out:
# <AxesSubplot:xlabel='createdat'>
